# %% [markdown]
# ### Importando Bibliotecas

# %%
import pandas as pd
import numpy as np

# %%
dados = pd.read_csv(r'C:\Users\Samuel Natividade\Desktop\Python Files\Bootcamp Alura\A223954189_28_143_208.csv', sep = ';', skiprows = 3, encoding = 'ISO-8859-1', skipfooter = 12, thousands= '.', decimal = ',')
dados.head()
## skiprows - pula as linhas de cima
## skipfooter - pula as linhas de baixo
# Out:
# <ipython-input-2-d36edc67c12d>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dados = pd.read_csv(r'C:\Users\Samuel Natividade\Desktop\Python Files\Bootcamp Alura\A223954189_28_143_208.csv', sep = ';', skiprows = 3, encoding = 'ISO-8859-1', skipfooter = 12, thousands= '.', decimal = ',')
#   Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 0          11 Rondônia   1388528.39   2931283.42   1541682.52   1525314.96
# 1              12 Acre    902416.00   1497206.26   1794028.48   1730469.42
# 2          13 Amazonas   4735529.42   7118990.57   8196635.49   8259378.42
# 3           14 Roraima    657889.53    777939.31    718688.03    839994.39
# 4              15 Pará  18864744.11  19553758.20  21937342.70  20842829.69
#
#       2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# ...

# %%
dados.tail()
# Out:
#      Unidade da Federação     2008/Jan     2008/Fev     2008/Mar     2008/Abr  \
# 22   43 Rio Grande do Sul  30931325.46  57363420.01  51547794.07  56673338.49
# 23  50 Mato Grosso do Sul   5377392.11   7002472.61   8423933.19   8797487.68
# 24         51 Mato Grosso   4795299.01   8684882.23   7886243.14   8794109.79
# 25               52 Goiás  15310637.29  22258668.68  21442515.75  20921212.45
# 26    53 Distrito Federal   4745919.19   7632480.67   9647203.26  11098732.99
#
#        2008/Mai     2008/Jun     2008/Jul     2008/Ago     2008/Set  ...  \
# 22  48397733.07  52413429.62  56636376.98  56113054.70  55356224.30  ...
# 23   9770421.80  10905392.18  10249299.82   9671553.45  10218511.05  ...
# 24   9231645.40  10221763.77   9163314.28   9243148.81   9052354.89  ...
# 25  21615970.67  18270043.87  20540517.13  20650730.67  20868443.56  ...
# 26  12891719.72  12850125.67  12565646.74  13710857.89  13165106.20  ...
#
# ...

# %%
dados.mean()
# Out:
# 2008/Jan    1.512685e+07
# 2008/Fev    2.271016e+07
# 2008/Mar    2.459419e+07
# 2008/Abr    2.543196e+07
# 2008/Mai    2.651125e+07
#                 ...
# 2020/Dez    5.337776e+07
# 2021/Jan    5.607375e+07
# 2021/Fev    5.557823e+07
# 2021/Mar    6.250230e+07
# Total       6.388213e+09
# Length: 159, dtype: float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 161 entries, Unidade da Federação to Total
# dtypes: float64(159), object(2)
# memory usage: 34.1+ KB

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2020/Dez     53377763.15
# 2021/Jan     56073748.02
# 2021/Fev     55578233.31
# 2021/Mar     62502301.42
# Total      6388213338.48
# Length: 159, dtype: float64

# %%
dados.columns
# Out:
# Index(['Unidade da Federação', '2008/Jan', '2008/Fev', '2008/Mar', '2008/Abr',
#        '2008/Mai', '2008/Jun', '2008/Jul', '2008/Ago', '2008/Set',
#        ...
#        '2020/Jul', '2020/Ago', '2020/Set', '2020/Out', '2020/Nov', '2020/Dez',
#        '2021/Jan', '2021/Fev', '2021/Mar', 'Total'],
#       dtype='object', length=161)

# %%
dados['2008/Ago'].mean()
# Out:
# 27800320.306666665

# %%
dados.plot(x = 'Unidade da Federação', y = '2008/Ago', kind = 'bar', figsize = (10,7))
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
ax = dados.sort_values('2008/Ago', ascending = False).plot(x = 'Unidade da Federação', y = '2008/Ago', kind = 'bar', figsize = (10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}') )
plt.title('Estados do Sul e Sudeste lideram em gastos com procedimentos hospitalares em agosto de 2008', fontsize = 14);

# %%
ax = dados.sort_values('2021/Mar', ascending = False).plot(x = 'Unidade da Federação', y = '2021/Mar', kind = 'bar', figsize = (10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}') )
plt.title('Valor por unidade por federacao', fontsize = 14);

# %% [markdown]
# ## Outro dataset

# %%
dados = pd.read_csv(r'C:\Users\Samuel Natividade\Desktop\Python Files\Bootcamp Alura\A152641189_28_143_208.csv', sep = ';', skiprows = 3, encoding = 'ISO-8859-1', skipfooter = 12, thousands= '.', decimal = ',')
dados
# Out:
# <ipython-input-13-c65c9d03650b>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dados = pd.read_csv(r'C:\Users\Samuel Natividade\Desktop\Python Files\Bootcamp Alura\A152641189_28_143_208.csv', sep = ';', skiprows = 3, encoding = 'ISO-8859-1', skipfooter = 12, thousands= '.', decimal = ',')
#       Unidade da Federação  1992/Mar  1992/Abr  1993/Mai  1993/Dez  1994/Jan  \
# 0              11 Rondônia         -         -         -         -         -
# 1                  12 Acre         -         -         -         -         -
# 2              13 Amazonas         -         -         -         -         -
# 3               14 Roraima         -         -         -         -         -
# 4                  15 Pará         -         -         -         -         -
# 5                 16 Amapá         -         -         -         -         -
# ...

# %%
dados[['2008/Ago', '2008/Set']]
# Out:
#        2008/Ago     2008/Set
# 0    2938286.29   2843930.91
# 1    1886871.84   2084884.80
# 2    8331763.97   8148089.92
# 3    1045291.11   1003740.89
# 4   23259148.28  23667690.01
# 5    1550340.63   1550166.99
# 6    5213290.38   5201400.94
# 7   14609872.57  15317881.85
# 8   10645917.52  11037940.55
# 9   29304821.51  30435026.82
# 10  10812840.19  11258681.53
# 11  12673774.35  12790639.17
# 12  31705296.79  30703879.20
# 13   9262767.68   9228201.96
# 14   4543252.50   4525676.82
# 15  43254543.33  42851268.02
# 16  80374117.08  82409129.30
# 17  12384068.19  12486952.61
# 18  42500830.29  43066461.47
# 19 180005050.15 180151656.17
# 20  56699001.13  58091985.79
# 21  28887854.62  30725718.78
# 22  56233758.74  57910170.98
# 23   9602843.49  10272466.74
# 24   8987811.95   8843061.60
# 25  21054991.27  21410602.15
# 26  11548451.89  12422577.60

# %%
# colunas que vamos utilizar
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, 'Unidade da Federação')
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
dados[colunas_usaveis]
# Out:
#       Unidade da Federação   2007/Ago   2007/Set    2007/Out    2007/Nov  \
# 0              11 Rondônia    4209.37   16397.03   133645.19   346912.84
# 1                  12 Acre   10470.07   14001.71    86200.85   301323.68
# 2              13 Amazonas   35752.72   45570.64   416012.30  2020381.79
# 3               14 Roraima    4785.91   11858.63    43852.67   369328.51
# 4                  15 Pará  181159.29  433414.74  1893197.50  5105406.44
# 5                 16 Amapá   33672.74  104822.98   118378.28   226661.18
# 6             17 Tocantins    4113.76   76633.06   343702.61  1068685.94
# 7              21 Maranhão  385330.18 1018352.93  2277717.78  4334468.23
# 8                 22 Piauí  220788.25  353468.67  1078182.68  2406035.32
# 9                 23 Ceará  357904.65  572356.18  1865065.71  5131814.39
# 10  24 Rio Grande do Norte  134605.36  272088.08   684678.30  1695824.89
# 11              25 Paraíba   97352.78  368130.43  1002088.64  2149873.40
# ...

# %%
usaveis = dados[colunas_usaveis]
usaveis = usaveis.set_index('Unidade da Federação')

# %%
usaveis
# Out:
#                          2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 11 Rondônia               4209.37   16397.03   133645.19   346912.84
# 12 Acre                  10470.07   14001.71    86200.85   301323.68
# 13 Amazonas              35752.72   45570.64   416012.30  2020381.79
# 14 Roraima                4785.91   11858.63    43852.67   369328.51
# 15 Pará                 181159.29  433414.74  1893197.50  5105406.44
# 16 Amapá                 33672.74  104822.98   118378.28   226661.18
# 17 Tocantins              4113.76   76633.06   343702.61  1068685.94
# 21 Maranhão             385330.18 1018352.93  2277717.78  4334468.23
# 22 Piauí                220788.25  353468.67  1078182.68  2406035.32
# 23 Ceará                357904.65  572356.18  1865065.71  5131814.39
# 24 Rio Grande do Norte  134605.36  272088.08   684678.30  1695824.89
# 25 Paraíba               97352.78  368130.43  1002088.64  2149873.40
# ...

# %%
usaveis['2019/Ago']
# Out:
# Unidade da Federação
# 11 Rondônia                8909111.89
# 12 Acre                    2981072.98
# 13 Amazonas               16493719.52
# 14 Roraima                 3181321.82
# 15 Pará                   36462011.47
# 16 Amapá                   2173060.89
# 17 Tocantins               7140062.79
# 21 Maranhão               31374933.66
# 22 Piauí                  17833872.84
# 23 Ceará                  51672585.01
# 24 Rio Grande do Norte    23073542.40
# 25 Paraíba                19863848.57
# 26 Pernambuco             71735983.26
# 27 Alagoas                17668105.59
# 28 Sergipe                10075280.52
# 29 Bahia                  77884805.29
# 31 Minas Gerais          161774658.77
# 32 Espírito Santo         29318260.49
# 33 Rio de Janeiro         83624113.30
# 35 São Paulo             303584114.00
# 41 Paraná                127174381.95
# 42 Santa Catarina         64503540.72
# 43 Rio Grande do Sul      98566147.88
# 50 Mato Grosso do Sul     19217982.14
# ...

# %%
usaveis.loc['12 Acre']
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Dez     3711660.71
# 2021/Jan     3005561.16
# 2021/Fev     2272733.90
# 2021/Mar     1137341.65
# Total      450048530.47
# Name: 12 Acre, Length: 165, dtype: float64

# %%
usaveis.T
# Out:
# Unidade da Federação  11 Rondônia      12 Acre   13 Amazonas   14 Roraima  \
# 2007/Ago                  4209.37     10470.07      35752.72      4785.91
# 2007/Set                 16397.03     14001.71      45570.64     11858.63
# 2007/Out                133645.19     86200.85     416012.30     43852.67
# 2007/Nov                346912.84    301323.68    2020381.79    369328.51
# 2007/Dez                711758.31    769612.36    5949408.99    470676.43
# ...                           ...          ...           ...          ...
# 2020/Dez               9003402.23   3711660.71   21546059.48   3125021.90
# 2021/Jan               8414690.60   3005561.16   24439059.57   3209323.68
# 2021/Fev               6039419.59   2272733.90   13679358.06   3044798.77
# 2021/Mar               4732441.04   1137341.65    6799060.80   2381844.31
# Total                996411254.68 450048530.47 1917247936.05 328876965.09
#
# Unidade da Federação       15 Pará     16 Amapá  17 Tocantins   21 Maranhão  \
# ...

# %%
usaveis = usaveis.drop('Total', axis = 1)

# %%
ax = dados.sort_values('2021/Mar', ascending = False).plot(x = 'Unidade da Federação', y = '2021/Mar', kind = 'bar', figsize = (10,7))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}') )
plt.title('Valor por unidade por federacao', fontsize = 14);

# %%
import matplotlib.ticker as ticker
ax = usaveis.T.plot(figsize = (10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title('Gastos por estados', fontsize = 14)
ax.grid(True)
ax.legend(loc='right', bbox_to_anchor=(1.35, 0.5))

# %%
ax = usaveis.T.plot(figsize = (10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title('Gastos por estados', fontsize = 14)
ax.grid(True)
ax.legend(loc='right', bbox_to_anchor=(1.35, 0.5))

# %%
# plotando 5 estados
ax = usaveis.T.iloc[:, 0:5].plot(figsize = (10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title('Gastos por estados', fontsize = 14)
ax.grid(True)
ax.legend(loc='right', bbox_to_anchor=(1.2, 0.5))

# %%
import numpy as np
# valor que classifica setta a aleeatoriedade
np.random.seed(687942)
usaveis.sample(n = 7)
# Out:
#                         2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 32 Espírito Santo       57408.11  284224.80  1152115.25  2296383.23
# 31 Minas Gerais        971394.37 2861781.50 10018011.35 21730281.63
# 24 Rio Grande do Norte 134605.36  272088.08   684678.30  1695824.89
# 17 Tocantins             4113.76   76633.06   343702.61  1068685.94
# 53 Distrito Federal    191951.47  769966.25  2165619.56  3813256.48
# 50 Mato Grosso do Sul  199556.12  573675.41  1069816.66  1995899.52
# 16 Amapá                33672.74  104822.98   118378.28   226661.18
#
#                           2007/Dez     2008/Jan    2008/Fev    2008/Mar  \
# Unidade da Federação
# 32 Espírito Santo       5724199.54  16212109.41 10032886.43 12262049.08
# 31 Minas Gerais        43429517.54 206208080.90 70301089.50 79119005.51
# 24 Rio Grande do Norte  4730811.68  11763899.23  9110108.87 10126626.54
# 17 Tocantins            3022200.87   5136474.61  5051932.07  5200151.87
# ...

# %% [markdown]
# ## Criar uma coluna com a região

# %%
usaveis['Total'] = usaveis.sum(axis = 1)
usaveis
# Out:
#                          2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 11 Rondônia               4209.37   16397.03   133645.19   346912.84
# 12 Acre                  10470.07   14001.71    86200.85   301323.68
# 13 Amazonas              35752.72   45570.64   416012.30  2020381.79
# 14 Roraima                4785.91   11858.63    43852.67   369328.51
# 15 Pará                 181159.29  433414.74  1893197.50  5105406.44
# 16 Amapá                 33672.74  104822.98   118378.28   226661.18
# 17 Tocantins              4113.76   76633.06   343702.61  1068685.94
# 21 Maranhão             385330.18 1018352.93  2277717.78  4334468.23
# 22 Piauí                220788.25  353468.67  1078182.68  2406035.32
# 23 Ceará                357904.65  572356.18  1865065.71  5131814.39
# 24 Rio Grande do Norte  134605.36  272088.08   684678.30  1695824.89
# 25 Paraíba               97352.78  368130.43  1002088.64  2149873.40
# ...

# %%
ordernado_por_total = usaveis.sort_values('Total', ascending = False)
ordernado_por_total = ordernado_por_total.drop('Total', axis = 1)

# %%
ordernado_por_total.head()
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná             554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul 1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 35 São Paulo         76668547.41 1038067423.15 172961999.58 170556696.16
# 31 Minas Gerais      43429517.54  206208080.90  70301089.50  79119005.51
# 41 Paraná            28790722.87   58081334.45  48855046.46  55611791.07
# 43 Rio Grande do Sul 30134255.70   51064610.03  45897704.82  52928695.92
# 33 Rio de Janeiro    13627123.27  251511992.03  44128159.73  42900847.02
#
# ...

# %%
# plotando 5 estados
ax = ordernado_por_total.T.iloc[:, 0:5].plot(figsize = (10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title('Gastos por estados', fontsize = 14)
ax.grid(True)
ax.legend(loc='right', bbox_to_anchor=(1.3, 0.5))

# %% [markdown]
# ## Adicionar o meu estado nesse imagem gráfico

# %%
# filtrei os dados dos top 5 estados
cinco_primeiros = ordernado_por_total.iloc[0:5]
cinco_primeiros
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná             554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul 1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 35 São Paulo         76668547.41 1038067423.15 172961999.58 170556696.16
# 31 Minas Gerais      43429517.54  206208080.90  70301089.50  79119005.51
# 41 Paraná            28790722.87   58081334.45  48855046.46  55611791.07
# 43 Rio Grande do Sul 30134255.70   51064610.03  45897704.82  52928695.92
# 33 Rio de Janeiro    13627123.27  251511992.03  44128159.73  42900847.02
#
# ...

# %%
# identifiquei qual a posição do estado pará
ordernado_por_total.index
# Out:
# Index(['35 São Paulo', '31 Minas Gerais', '41 Paraná', '43 Rio Grande do Sul',
#        '33 Rio de Janeiro', '29 Bahia', '26 Pernambuco', '42 Santa Catarina',
#        '23 Ceará', '52 Goiás', '15 Pará', '21 Maranhão', '32 Espírito Santo',
#        '24 Rio Grande do Norte', '25 Paraíba', '53 Distrito Federal',
#        '50 Mato Grosso do Sul', '22 Piauí', '27 Alagoas', '51 Mato Grosso',
#        '13 Amazonas', '28 Sergipe', '17 Tocantins', '11 Rondônia', '12 Acre',
#        '14 Roraima', '16 Amapá'],
#       dtype='object', name='Unidade da Federação')

# %%
# criei um datafrace slice só com o estado do pará
meu_estado = ordernado_por_total.iloc[10:11,:]
meu_estado
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
#                         2008/Mai  ...    2020/Jun    2020/Jul    2020/Ago  \
# Unidade da Federação              ...
# 15 Pará              23861080.80  ... 40994545.21 40496349.97 38793393.54
#
#                         2020/Set    2020/Out    2020/Nov    2020/Dez  \
# Unidade da Federação
# 15 Pará              36965951.76 38406616.21 37043032.10 36914437.92
#
#                         2021/Jan    2021/Fev    2021/Mar
# Unidade da Federação
# 15 Pará              33887773.65 23343222.94 13069564.31
#
# [1 rows x 164 columns]

# %%
# fiz um append no dataframe do 5 estados + Pará
seis_estados = meu_estado.append(cinco_primeiros)
seis_estados
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 15 Pará               181159.29  433414.74  1893197.50  5105406.44
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná             554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul 1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 15 Pará              13162823.43   21762104.16  20126081.01  22149375.82
# 35 São Paulo         76668547.41 1038067423.15 172961999.58 170556696.16
# 31 Minas Gerais      43429517.54  206208080.90  70301089.50  79119005.51
# 41 Paraná            28790722.87   58081334.45  48855046.46  55611791.07
# 43 Rio Grande do Sul 30134255.70   51064610.03  45897704.82  52928695.92
# ...

# %%
# plotando 5 estados + Pará
ax = seis_estados.T.plot(figsize = (10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title('top 5 estados mais gastos + Pará', fontsize = 14)
ax.grid(True)
ax.legend(loc='right', bbox_to_anchor=(1.3, 0.5))

# %% [markdown]
# ## Criar uma coluna com a região

# %%
## 3 - Sudeste, 4 Sul, 2 Nordeste, 1 Norte, 5 Centro-Oeste
Regiao = []
for estados in ordernado_por_total.index.tolist():
    if estados[0] == '1': 
        Regiao.append('Norte')
    elif estados[0] == '2':
        Regiao.append('Nordeste')
    elif estados[0] == '3':
        Regiao.append('Sudeste')
    elif estados[0] == '4':
        Regiao.append('Sul')
    else:
         Regiao.append('Centro-Oeste')
print(Regiao)
# Out:
# ['Sudeste', 'Sudeste', 'Sul', 'Sul', 'Sudeste', 'Nordeste', 'Nordeste', 'Sul', 'Nordeste', 'Centro-Oeste', 'Norte', 'Nordeste', 'Sudeste', 'Nordeste', 'Nordeste', 'Centro-Oeste', 'Centro-Oeste', 'Nordeste', 'Nordeste', 'Centro-Oeste', 'Norte', 'Nordeste', 'Norte', 'Norte', 'Norte', 'Norte', 'Norte']

# %%
ordernado_por_total['Regiao'] = Regiao
ordernado_por_total
# Out:
#                          2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo           1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais         971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná               554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul   1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro       469469.34  921646.57  2994664.57  7250528.08
# 29 Bahia                135146.36  448349.75  1382038.11  3348779.62
# 26 Pernambuco           400640.85 1088340.42  2973553.48  6699828.82
# 42 Santa Catarina       693955.05 1092964.12  3562300.82  7578502.38
# 23 Ceará                357904.65  572356.18  1865065.71  5131814.39
# 52 Goiás                179395.82  418053.58  1198730.25  2712117.54
# 15 Pará                 181159.29  433414.74  1893197.50  5105406.44
# 21 Maranhão             385330.18 1018352.93  2277717.78  4334468.23
# ...

# %%
colunas_interessadas = ordernado_por_total.columns[6:]
ordenado_por_total_2 = ordernado_por_total[colunas_interessadas]

# %%
ordenado_por_total_2
# Out:
#                            2008/Fev     2008/Mar     2008/Abr     2008/Mai  \
# Unidade da Federação
# 35 São Paulo           172961999.58 170556696.16 170338163.23 172462057.87
# 31 Minas Gerais         70301089.50  79119005.51  79046322.41  79268070.12
# 41 Paraná               48855046.46  55611791.07  56115135.82  55574831.93
# 43 Rio Grande do Sul    45897704.82  52928695.92  51972416.77  51679350.79
# 33 Rio de Janeiro       44128159.73  42900847.02  45306499.53  43951349.46
# 29 Bahia                33410124.06  41316672.72  42826993.62  42086263.49
# 26 Pernambuco           26222079.10  30716361.81  30589332.79  31420089.90
# 42 Santa Catarina       24409572.92  27483480.50  27806641.44  28354279.52
# 23 Ceará                27643304.86  30085370.22  31376221.00  31189904.62
# 52 Goiás                18149374.27  20992213.03  21049477.30  19162546.79
# 15 Pará                 20126081.01  22149375.82  23436682.75  23861080.80
# ...

# %%
ax = ordenado_por_total_2.head(5).T[:-1].plot(figsize = (10,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title('Top 5 Estados mais gastos', fontsize = 14)
ax.grid(True)
ax.legend(loc='right', bbox_to_anchor=(1.3, 0.5))

# %% [markdown]
# ## googlar casos de dengue e se reflete nos gastos
#
# ## plotar só  os estados do sudeste e ver se afetou com um pico de 2012/2013 de forma similar nesses estados
#
# ## adicionar seu estado novamente

# %%
ordenado_por_total = usaveis.sort_values('Total', ascending = False)
ordenado_por_total['Regiao'] = Regiao

# %%
ordenado_por_total_sudeste = ordenado_por_total[ordenado_por_total['Regiao'] == 'Sudeste']
ordenado_por_total_sudeste
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
# 32 Espírito Santo      57408.11  284224.80  1152115.25  2296383.23
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 35 São Paulo         76668547.41 1038067423.15 172961999.58 170556696.16
# 31 Minas Gerais      43429517.54  206208080.90  70301089.50  79119005.51
# 33 Rio de Janeiro    13627123.27  251511992.03  44128159.73  42900847.02
# 32 Espírito Santo     5724199.54   16212109.41  10032886.43  12262049.08
#
#                          2008/Abr     2008/Mai  ...     2020/Ago     2020/Set  \
# Unidade da Federação                            ...
# 35 São Paulo         170338163.23 172462057.87  ... 350268671.25 338872478.49
# ...

# %%
colunas_interessadas = ordenado_por_total_sudeste.columns[6:]
ordenado_por_total_sudeste = ordenado_por_total_sudeste[colunas_interessadas]

# %% [markdown]
# Picos foram similares nos estados na região sudeste. somente o estado de São paulo que Rio de Janeiro que as vezes houve alguns picos diferenciados

# %%
meu_estado['Regiao'] = 'Norte'
meu_estado['Total'] = meu_estado.sum(axis = 1)
meu_estado
# Out:
# <ipython-input-45-665ea157c1d7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meu_estado['Regiao'] = 'Norte'
# <ipython-input-45-665ea157c1d7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meu_estado['Total'] = meu_estado.sum(axis = 1)
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
# ...

# %%
# colunas interessantes
colunas_interessadas_para = meu_estado.columns[6:]
meu_estado = meu_estado[colunas_interessadas_para]
meu_estado
# Out:
#                         2008/Fev    2008/Mar    2008/Abr    2008/Mai  \
# Unidade da Federação
# 15 Pará              20126081.01 22149375.82 23436682.75 23861080.80
#
#                         2008/Jun    2008/Jul    2008/Ago    2008/Set  \
# Unidade da Federação
# 15 Pará              23502915.90 22544291.26 23259148.28 23667690.01
#
#                         2008/Out    2008/Nov  ...    2020/Ago    2020/Set  \
# Unidade da Federação                          ...
# 15 Pará              23352577.75 23537613.41  ... 38793393.54 36965951.76
#
#                         2020/Out    2020/Nov    2020/Dez    2021/Jan  \
# Unidade da Federação
# 15 Pará              38406616.21 37043032.10 36914437.92 33887773.65
#
#                         2021/Fev    2021/Mar  Regiao         Total
# Unidade da Federação
# 15 Pará              23343222.94 13069564.31   Norte 4705290466.69
#
# [1 rows x 160 columns]

# %%
sudeste_e_para = ordenado_por_total_sudeste.append(meu_estado)
sudeste_e_para
# Out:
#                          2008/Fev     2008/Mar     2008/Abr     2008/Mai  \
# Unidade da Federação
# 35 São Paulo         172961999.58 170556696.16 170338163.23 172462057.87
# 31 Minas Gerais       70301089.50  79119005.51  79046322.41  79268070.12
# 33 Rio de Janeiro     44128159.73  42900847.02  45306499.53  43951349.46
# 32 Espírito Santo     10032886.43  12262049.08  12453466.98  11789786.09
# 15 Pará               20126081.01  22149375.82  23436682.75  23861080.80
#
#                          2008/Jun     2008/Jul     2008/Ago     2008/Set  \
# Unidade da Federação
# 35 São Paulo         175492995.85 179569910.06 180005050.15 180151656.17
# 31 Minas Gerais       79619189.20  82209206.98  80374117.08  82409129.30
# 33 Rio de Janeiro     44111107.27  44359056.71  42500830.29  43066461.47
# 32 Espírito Santo     11889687.35  12205584.14  12384068.19  12486952.61
# 15 Pará               23502915.90  22544291.26  23259148.28  23667690.01
#
# ...

# %%
ax = sudeste_e_para.T[:-2].plot(figsize = (10,6))
ax.set_yticklabels(['{:,.0f}'.format(x) + 'Milhões' for x in ax.get_yticks()/1000000])
plt.title('Gastos hospitalares da Região Sudeste e Pará', fontsize = 14)
ax.grid(True)
ax.legend(loc='right', bbox_to_anchor=(1.3, 0.5))
# Out:
# <ipython-input-48-c67e1f539885>:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:,.0f}'.format(x) + 'Milhões' for x in ax.get_yticks()/1000000])

# %% [markdown]
# ## Falta pegar dados da Dengue

# %%
dados_dengue = pd.read_csv(r'C:\Users\Samuel Natividade\Desktop\Python Files\Bootcamp Alura\A115521189_28_143_208.csv', sep = ';', skiprows = 4, encoding = 'ISO-8859-1', skipfooter = 12, thousands= '.', decimal = ',')
dados_dengue.head()
## skiprows - pula as linhas de cima
## skipfooter - pula as linhas de baixo
# Out:
# <ipython-input-49-0d88afd85d80>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dados_dengue = pd.read_csv(r'C:\Users\Samuel Natividade\Desktop\Python Files\Bootcamp Alura\A115521189_28_143_208.csv', sep = ';', skiprows = 4, encoding = 'ISO-8859-1', skipfooter = 12, thousands= '.', decimal = ',')
#   Unidade da Federação 2007/Jul 2007/Ago 2007/Set 2007/Out 2007/Nov 2007/Dez  \
# 0          11 Rondônia        -        -        -        -        2       77
# 1              12 Acre        -        -        -        -        1        3
# 2          13 Amazonas        -        -        -        -        1       61
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        4       12       38      163      610
#
#    2008/Jan  2008/Fev  2008/Mar  ...  2020/Jul  2020/Ago 2020/Set 2020/Out  \
# ...

# %%
dados_dengue = dados_dengue.set_index('Unidade da Federação')
dados_dengue.head()
# Out:
#                      2007/Jul 2007/Ago 2007/Set 2007/Out 2007/Nov 2007/Dez  \
# Unidade da Federação
# 11 Rondônia                 -        -        -        -        2       77
# 12 Acre                     -        -        -        -        1        3
# 13 Amazonas                 -        -        -        -        1       61
# 14 Roraima                  -        -        -        -        -        -
# 15 Pará                     -        4       12       38      163      610
#
#                       2008/Jan  2008/Fev  2008/Mar  2008/Abr  ...  2020/Jul  \
# Unidade da Federação                                          ...
# 11 Rondônia                202       237       237       209  ...        15
# 12 Acre                     15        13        12        24  ...         5
# 13 Amazonas                175       246       248       209  ...        20
# 14 Roraima                   7        13        32        90  ...         1
# ...

# %%
dados_dengue.replace('-', 0, inplace = True)
dados_dengue.head()
# Out:
#                      2007/Jul 2007/Ago 2007/Set 2007/Out 2007/Nov 2007/Dez  \
# Unidade da Federação
# 11 Rondônia                 0        0        0        0        2       77
# 12 Acre                     0        0        0        0        1        3
# 13 Amazonas                 0        0        0        0        1       61
# 14 Roraima                  0        0        0        0        0        0
# 15 Pará                     0        4       12       38      163      610
#
#                       2008/Jan  2008/Fev  2008/Mar  2008/Abr  ...  2020/Jul  \
# Unidade da Federação                                          ...
# 11 Rondônia                202       237       237       209  ...        15
# 12 Acre                     15        13        12        24  ...         5
# 13 Amazonas                175       246       248       209  ...        20
# 14 Roraima                   7        13        32        90  ...         1
# ...

# %%
dados_dengue = dados_dengue.astype(int)

# %%
## vamos plotar o número de casos internação de dengue 
Regiao = []
for estados in dados_dengue.index.tolist():
    if estados[0] == '1': 
        Regiao.append('Norte')
    elif estados[0] == '2':
        Regiao.append('Nordeste')
    elif estados[0] == '3':
        Regiao.append('Sudeste')
    elif estados[0] == '4':
        Regiao.append('Sul')
    else:
         Regiao.append('Centro-Oeste')
print(Regiao)
# Out:
# ['Norte', 'Norte', 'Norte', 'Norte', 'Norte', 'Norte', 'Norte', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Sudeste', 'Sudeste', 'Sudeste', 'Sudeste', 'Sul', 'Sul', 'Sul', 'Centro-Oeste', 'Centro-Oeste', 'Centro-Oeste', 'Centro-Oeste']

# %%
dados_dengue['Regiao'] = Regiao
dados_dengue.head()
# Out:
#                       2007/Jul  2007/Ago  2007/Set  2007/Out  2007/Nov  \
# Unidade da Federação
# 11 Rondônia                  0         0         0         0         2
# 12 Acre                      0         0         0         0         1
# 13 Amazonas                  0         0         0         0         1
# 14 Roraima                   0         0         0         0         0
# 15 Pará                      0         4        12        38       163
#
#                       2007/Dez  2008/Jan  2008/Fev  2008/Mar  2008/Abr  ...  \
# Unidade da Federação                                                    ...
# 11 Rondônia                 77       202       237       237       209  ...
# 12 Acre                      3        15        13        12        24  ...
# 13 Amazonas                 61       175       246       248       209  ...
# 14 Roraima                   0         7        13        32        90  ...
# ...

# %%
dados_dengue['Total'] = dados_dengue.sum(axis = 1)
dados_dengue
# Out:
#                         2007/Jul  2007/Ago  2007/Set  2007/Out  2007/Nov  \
# Unidade da Federação
# 11 Rondônia                    0         0         0         0         2
# 12 Acre                        0         0         0         0         1
# 13 Amazonas                    0         0         0         0         1
# 14 Roraima                     0         0         0         0         0
# 15 Pará                        0         4        12        38       163
# 16 Amapá                       0         0         0         1         0
# 17 Tocantins                   0         0         0         1        10
# 21 Maranhão                    0        17        23        24        43
# 22 Piauí                       0         0         0         2         1
# 23 Ceará                       0         1         6        11        34
# 24 Rio Grande do Norte         1         5         5        11        32
# ...

# %%
dados_dengue_sudeste = dados_dengue[dados_dengue['Regiao'] == 'Sudeste']
dados_dengue_sudeste
# Out:
#                       2007/Jul  2007/Ago  2007/Set  2007/Out  2007/Nov  \
# Unidade da Federação
# 31 Minas Gerais              0         0         0         0         2
# 32 Espírito Santo            0         0         0         0         5
# 33 Rio de Janeiro            0         0         0         8        21
# 35 São Paulo                 0         0         0         1         7
#
#                       2007/Dez  2008/Jan  2008/Fev  2008/Mar  2008/Abr  ...  \
# Unidade da Federação                                                    ...
# 31 Minas Gerais             21        63       105       370       919  ...
# 32 Espírito Santo           21        74        82       306       506  ...
# 33 Rio de Janeiro          204      1064      1704      4996      5669  ...
# 35 São Paulo                30        82        85       189       313  ...
#
#                       2020/Ago  2020/Set  2020/Out  2020/Nov  2020/Dez  \
# Unidade da Federação
# ...

# %%
dados_dengue_sudeste = dados_dengue_sudeste.sort_values(by = 'Total', ascending = False)

# %%
ax = ordenado_por_total_sudeste.T[:-2].plot(figsize = (10,6))
ax.set_yticklabels(['{:,.0f}'.format(x) + 'Milhões' for x in ax.get_yticks()/1000000])
plt.title('Gastos hospitalares da Região Sudeste', fontsize = 14)
ax.grid(True)
ax.legend(loc='right', bbox_to_anchor=(1.3, 0.5))
plt.show()

ax1 = dados_dengue_sudeste.T[:-2].plot(figsize = (10,6))
plt.title('Qtdade de Pessoas com dengue na regiao Sudeste', fontsize = 14)
ax1.grid(True)
ax1.legend(loc='right', bbox_to_anchor=(1.3, 0.5))
plt.show()
# Out:
# <ipython-input-58-568de1113f56>:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:,.0f}'.format(x) + 'Milhões' for x in ax.get_yticks()/1000000])

# %%
ordenado_por_total_sudeste.dtypes
# Out:
# 2008/Fev    float64
# 2008/Mar    float64
# 2008/Abr    float64
# 2008/Mai    float64
# 2008/Jun    float64
#              ...
# 2021/Jan    float64
# 2021/Fev    float64
# 2021/Mar    float64
# Total       float64
# Regiao       object
# Length: 160, dtype: object

# %% [markdown]
# ## Aula 4

# %%
ordenado_por_total_2[ordenado_por_total_2.columns[48:150]].head(3).T.plot(figsize = (10,6))
# Out:
# <AxesSubplot:>

# %%
ordenado_por_total_2[ordenado_por_total_2.columns[-36:-2]].head(3).T.plot(figsize = (10,6))
# Out:
# <AxesSubplot:>

# %%
mes_mais_recente = ordenado_por_total_2.columns[-2]

# %%
gastos_do_mais_recente = ordenado_por_total_2[mes_mais_recente]
gastos_do_mais_recente.head()
# Out:
# Unidade da Federação
# 35 São Paulo           177408317.71
# 31 Minas Gerais         79780838.00
# 41 Paraná               43480729.07
# 43 Rio Grande do Sul    37798832.80
# 33 Rio de Janeiro       49149884.48
# Name: 2021/Mar, dtype: float64

# %%
gastos_do_mais_recente.plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='2021/Mar'>

# %%
gastos_do_mais_recente / gastos_do_mais_recente.loc['33 Rio de Janeiro']
# Out:
# Unidade da Federação
# 35 São Paulo             3.61
# 31 Minas Gerais          1.62
# 41 Paraná                0.88
# 43 Rio Grande do Sul     0.77
# 33 Rio de Janeiro        1.00
# 29 Bahia                 0.64
# 26 Pernambuco            0.80
# 42 Santa Catarina        0.39
# 23 Ceará                 0.35
# 52 Goiás                 0.51
# 15 Pará                  0.27
# 21 Maranhão              0.35
# 32 Espírito Santo        0.32
# 24 Rio Grande do Norte   0.18
# 25 Paraíba               0.25
# 53 Distrito Federal      0.30
# 50 Mato Grosso do Sul    0.08
# 22 Piauí                 0.19
# 27 Alagoas               0.17
# 51 Mato Grosso           0.18
# 13 Amazonas              0.14
# 28 Sergipe               0.06
# 17 Tocantins             0.02
# 11 Rondônia              0.10
# 12 Acre                  0.02
# 14 Roraima               0.05
# 16 Amapá                 0.02
# Name: 2021/Mar, dtype: float64

# %%
## criar a tabela de comparaçao com seu estado
gastos_do_mais_recente / gastos_do_mais_recente.loc['15 Pará']
# Out:
# Unidade da Federação
# 35 São Paulo             13.57
# 31 Minas Gerais           6.10
# 41 Paraná                 3.33
# 43 Rio Grande do Sul      2.89
# 33 Rio de Janeiro         3.76
# 29 Bahia                  2.40
# 26 Pernambuco             3.02
# 42 Santa Catarina         1.48
# 23 Ceará                  1.31
# 52 Goiás                  1.90
# 15 Pará                   1.00
# 21 Maranhão               1.32
# 32 Espírito Santo         1.19
# 24 Rio Grande do Norte    0.67
# 25 Paraíba                0.96
# 53 Distrito Federal       1.13
# 50 Mato Grosso do Sul     0.31
# 22 Piauí                  0.73
# 27 Alagoas                0.63
# 51 Mato Grosso            0.68
# 13 Amazonas               0.52
# 28 Sergipe                0.24
# 17 Tocantins              0.07
# 11 Rondônia               0.36
# 12 Acre                   0.09
# 14 Roraima                0.18
# 16 Amapá                  0.08
# Name: 2021/Mar, dtype: float64

# %%
(gastos_do_mais_recente / gastos_do_mais_recente.loc['33 Rio de Janeiro']).head()
# Out:
# Unidade da Federação
# 35 São Paulo           3.61
# 31 Minas Gerais        1.62
# 41 Paraná              0.88
# 43 Rio Grande do Sul   0.77
# 33 Rio de Janeiro      1.00
# Name: 2021/Mar, dtype: float64

# %%
gastos_do_mais_recente.plot(kind = 'bar')
plt.grid(True)

# %%
gastos_do_mais_recente = gastos_do_mais_recente.sort_values(ascending = False)
gastos_do_mais_recente.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %% [markdown]
# ## Desafio: Gráfico de Barra do gasto dos outros estados em função do seu estado

# %%
plt.figure(figsize = (10,6))
(gastos_do_mais_recente / gastos_do_mais_recente.loc['15 Pará']).plot(kind = 'bar')
plt.title('Gastos dos estados em comparação com o Pará')
plt.show()

# %%
gastos_proporcionais = gastos_do_mais_recente / gastos_do_mais_recente.sum()

# %%
gastos_proporcionais.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %% [markdown]
# ## Módulo 2 - Visualização de dados com Seaborn e Matplotlib

# %%
dados_populacao = """Posição	Unidade federativa	População	% da pop. total	País comparável
(habitantes)

1	 São Paulo	46 289 333	21,9%	Flag of Spain.svg Espanha (46 439 864)
2	 Minas Gerais	21 292 666	10,1%	 Sri Lanka (20 675 000)
3	 Rio de Janeiro	17 366 189	8,2%	 Países Baixos (16 922 900)
4	Bahia Bahia	14 930 634	7,1%	 Chade (14 037 000)
5	 Paraná	11 516 840	5,4%	 Bolívia (11 410 651)
6	 Rio Grande do Sul	11 422 973	5,4%	 Bélgica (11 250 659)
7	 Pernambuco	9 616 621	4,5%	 Bielorrússia (9 485 300)
8	 Ceará	9 187 103	4,3%	 Emirados Árabes Unidos (9 157 000)
9	Pará Pará	8 690 745	4,1%	 Áustria (8 602 112)
10	 Santa Catarina	7 252 502	3,4%	 Sérvia (7 114 393)
11	 Maranhão	7 114 598	3,4%	 Paraguai (7 003 406)
12	 Goiás	7 113 540	3,4%	 Paraguai (7 003 406)
13	 Amazonas	4 207 714	2,0%	 Líbano (4 168 000)
14	 Espírito Santo	4 064 052	1,9%	 Líbano (4 168 000)
15	 Paraíba	4 039 277	1,9%	 Líbano (4 168 000)
16	 Rio Grande do Norte	3 534 165	1,7%	 Uruguai (3 415 866)
17	 Mato Grosso	3 526 220	1,7%	 Uruguai (3 415 866)
18	 Alagoas	3 351 543	1,6%	 Uruguai (3 415 866)
19	 Piauí	3 281 480	1,6%	 Kuwait (3 268 431)
20	 Distrito Federal	3 055 149	1,4%	 Lituânia (2 900 787)
21	 Mato Grosso do Sul	2 809 394	1,3%	 Jamaica (2 717 991)
22	 Sergipe	2 318 822	1,1%	 Namíbia (2 280 700)
23	 Rondônia	1 796 460	0,8%	 Gabão (1 725 000)
24	 Tocantins	1 590 248	0,7%	 Bahrein (1 359 800)
25	 Acre	894 470	0,4%	 Fiji (859 178)
26	 Amapá	861 773	0,4%	 Fiji (859 178)
27	 Roraima	631 181	0,3%	 Luxemburgo (562 958)"""

# %%
from io import StringIO

dados_da_populacao_io = StringIO(dados_populacao)
dados_populacao = pd.read_csv(dados_da_populacao_io, sep = '\t')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-e62891047c07> in <module>
#       1 from io import StringIO
#       2
# ----> 3 dados_da_populacao_io = StringIO(dados_populacao)
#       4 dados_populacao = pd.read_csv(dados_da_populacao_io, sep = '\t')
#
# TypeError: initial_value must be str or None, not DataFrame

# %% [markdown]
# ## Desafio1: Ler o arquivo diretamente da página da internet

# %% [markdown]
# ## Desafio2: Alterar o indíce, deve ser a coluna UF, dropar a coluna % da população e país comparável, mudar o nome das colunas para minúsculo

# %%
# excluindo a primeira linha
dados_populacao = dados_populacao[1:]
dados_populacao.head()
# Out:
#                     populacao
# unidade_federativa
#  Minas Gerais        21292666
#  Rio de Janeiro      17366189
# Bahia Bahia          14930634
#  Paraná              11516840
#  Rio Grande do Sul   11422973

# %%
## dropando as colunas que não vao ser utilizadas
dados_populacao = dados_populacao.drop(['% da pop. total', 'País comparável'], axis = 1)

# %%
dados_populacao.head()
# Out:
#   Posição Unidade federativa   População
# 1       1          São Paulo  46 289 333
# 2       2       Minas Gerais  21 292 666
# 3       3     Rio de Janeiro  17 366 189
# 4       4        Bahia Bahia  14 930 634
# 5       5             Paraná  11 516 840

# %%
# mudando o nome das colunas
dados_populacao.rename(columns = {'Posição': 'posicao', 'Unidade federativa': 'unidade_federativa', 'População': 'populacao'},
inplace = True)
dados_populacao.head()
# Out:
#   posicao unidade_federativa   populacao
# 1       1          São Paulo  46 289 333
# 2       2       Minas Gerais  21 292 666
# 3       3     Rio de Janeiro  17 366 189
# 4       4        Bahia Bahia  14 930 634
# 5       5             Paraná  11 516 840

# %%
dados_populacao.set_index('unidade_federativa', inplace = True)
dados_populacao.head()
# Out:
#                    posicao   populacao
# unidade_federativa
#  São Paulo               1  46 289 333
#  Minas Gerais            2  21 292 666
#  Rio de Janeiro          3  17 366 189
# Bahia Bahia              4  14 930 634
#  Paraná                  5  11 516 840

# %%
dados_populacao = dados_populacao.drop(columns = 'posicao')

# %%
dados_populacao['populacao'] = dados_populacao['populacao'].str.replace(' ', '')
dados_populacao.head()
# Out:
#                    populacao
# unidade_federativa
#  São Paulo          46289333
#  Minas Gerais       21292666
#  Rio de Janeiro     17366189
# Bahia Bahia         14930634
#  Paraná             11516840

# %%
# transformando para dados numéricos
dados_populacao['populacao'] = dados_populacao['populacao'].astype(int)

# %%
dados_populacao.dtypes
# Out:
# populacao    int32
# dtype: object

# %%
gastos_do_mais_recente.index = gastos_do_mais_recente.index.str[3:]

# %%
gastos_do_mais_recente.head()
# Out:
# Unidade da Federação
# São Paulo        177408317.71
# Minas Gerais      79780838.00
# Rio de Janeiro    49149884.48
# Paraná            43480729.07
# Pernambuco        39472738.81
# Name: 2021/Mar, dtype: float64

# %%
# indices
dados_populacao.join(gastos_do_mais_recente)
# Out:
#                       populacao  2021/Mar
# unidade_federativa
#  Minas Gerais          21292666       NaN
#  Rio de Janeiro        17366189       NaN
# Bahia Bahia            14930634       NaN
#  Paraná                11516840       NaN
#  Rio Grande do Sul     11422973       NaN
#  Pernambuco             9616621       NaN
#  Ceará                  9187103       NaN
# Pará Pará               8690745       NaN
#  Santa Catarina         7252502       NaN
#  Maranhão               7114598       NaN
#  Goiás                  7113540       NaN
#  Amazonas               4207714       NaN
#  Espírito Santo         4064052       NaN
#  Paraíba                4039277       NaN
#  Rio Grande do Norte    3534165       NaN
#  Mato Grosso            3526220       NaN
#  Alagoas                3351543       NaN
#  Piauí                  3281480       NaN
#  Distrito Federal       3055149       NaN
#  Mato Grosso do Sul     2809394       NaN
#  Sergipe                2318822       NaN
# ...

# %%
dados_populacao.index = dados_populacao.index.str.strip()
dados_populacao.head()
# Out:
#                     populacao
# unidade_federativa
# Minas Gerais         21292666
# Rio de Janeiro       17366189
# Bahia Bahia          14930634
# Paraná               11516840
# Rio Grande do Sul    11422973

# %%
for estado in gastos_do_mais_recente.index:
    #print(f" {estado} {estado} >= {estado}")
    dados_populacao.index = dados_populacao.index.str.replace(f"{estado} {estado}", estado)
dados_populacao.index
# Out:
# Index(['Minas Gerais', 'Rio de Janeiro', 'Bahia', 'Paraná',
#        'Rio Grande do Sul', 'Pernambuco', 'Ceará', 'Pará', 'Santa Catarina',
#        'Maranhão', 'Goiás', 'Amazonas', 'Espírito Santo', 'Paraíba',
#        'Rio Grande do Norte', 'Mato Grosso', 'Alagoas', 'Piauí',
#        'Distrito Federal', 'Mato Grosso do Sul', 'Sergipe', 'Rondônia',
#        'Tocantins', 'Acre', 'Amapá', 'Roraima'],
#       dtype='object', name='unidade_federativa')

# %%
dados_populacao.join(gastos_do_mais_recente)
# Out:
#                      populacao    2021/Mar
# unidade_federativa
# Minas Gerais          21292666 79780838.00
# Rio de Janeiro        17366189 49149884.48
# Bahia                 14930634 31314602.44
# Paraná                11516840 43480729.07
# Rio Grande do Sul     11422973 37798832.80
# Pernambuco             9616621 39472738.81
# Ceará                  9187103 17173151.55
# Pará                   8690745 13069564.31
# Santa Catarina         7252502 19375822.56
# Maranhão               7114598 17294509.11
# Goiás                  7113540 24867001.02
# Amazonas               4207714  6799060.80
# Espírito Santo         4064052 15606368.11
# Paraíba                4039277 12517894.05
# Rio Grande do Norte    3534165  8733455.36
# Mato Grosso            3526220  8835890.09
# Alagoas                3351543  8180887.21
# Piauí                  3281480  9542151.53
# Distrito Federal       3055149 14731938.43
# Mato Grosso do Sul     2809394  4035989.77
# ...

# %% [markdown]
# ## Desafio3:  Estruturar uma funçao para leitura e limpeza dessa tabela, devolvendo a tabela de populaçao e a tabela unida
